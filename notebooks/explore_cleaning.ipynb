# %%
import pandas as pd
df = pd.read_parquet("../data/yellow_tripdata_2025-01.parquet")
df = df[df["payment_type"].isin([1, 2])]
df = df[df["fare_amount"] >= 3]
df["duration_min"] = (df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]).dt.total_seconds() / 60
df = df[df["duration_min"] >= 1]
df = df[(df["tpep_pickup_datetime"] >= "2025-01-01") & (df["tpep_pickup_datetime"] < "2025-02-01")]
df["speed_mph"] = df["trip_distance"] / (df["duration_min"] / 60)
df = df[(df["speed_mph"] > 1) & (df["speed_mph"] <= 100)]

len(df)
# Out:
# 2782410

# %%
cols = ["trip_distance", "duration_min", "speed_mph", "fare_amount", "total_amount"]
df[cols].describe()
# Out:
#        trip_distance  duration_min     speed_mph   fare_amount  total_amount
# count   2.782410e+06  2.782410e+06  2.782410e+06  2.782410e+06  2.782410e+06
# mean    3.172789e+00  1.464279e+01  1.126967e+01  1.783673e+01  2.732314e+01
# std     4.308191e+00  1.266346e+01  6.427382e+00  1.684726e+01  2.132538e+01
# min     2.000000e-02  1.000000e+00  1.000993e+00  3.000000e+00  4.500000e+00
# 25%     1.000000e+00  7.116667e+00  7.316642e+00  8.600000e+00  1.596000e+01
# 50%     1.630000e+00  1.138333e+01  9.514527e+00  1.210000e+01  2.040000e+01
# 75%     3.000000e+00  1.813333e+01  1.287209e+01  1.910000e+01  2.835000e+01
# max     2.659000e+02  5.022133e+03  9.940395e+01  2.450900e+03  2.506710e+03
