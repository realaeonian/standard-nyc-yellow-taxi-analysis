# %%
import pandas as pd
df = pd.read_parquet("../data/yellow_tripdata_2025-01.parquet")
df = df[df["payment_type"].isin([1, 2])]
df = df[df["fare_amount"] >= 3]
df["duration_min"] = (df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]).dt.total_seconds() / 60
df = df[df["duration_min"] >= 1]
df = df[(df["tpep_pickup_datetime"] >= "2025-01-01") & (df["tpep_pickup_datetime"] < "2025-02-01")]
df["speed_mph"] = df["trip_distance"] / (df["duration_min"] / 60)
df = df[(df["speed_mph"] > 1) & (df["speed_mph"] <= 100)]

len(df)
# Out:
# 2782410

# %%
cols = ["trip_distance", "duration_min", "speed_mph", "fare_amount", "total_amount"]
df[cols].describe()

df[df["PULocationID"] == df["DOLocationID"]]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 6               1  2025-01-01 00:14:47   2025-01-01 00:16:15              0.0
# 26              1  2025-01-01 00:48:06   2025-01-01 00:53:23              1.0
# 70              2  2025-01-01 00:55:23   2025-01-01 00:57:26              1.0
# ...           ...                  ...                   ...              ...
# 2934970         1  2025-01-31 23:21:39   2025-01-31 23:28:39              1.0
# 2934993         2  2025-01-31 23:05:44   2025-01-31 23:08:39              2.0
# 2935034         2  2025-01-31 23:01:16   2025-01-31 23:03:33              1.0
# 2935046         1  2025-01-31 23:38:10   2025-01-31 23:52:39              1.0
# 2935073         1  2025-01-31 23:11:28   2025-01-31 23:14:45              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2                 0.60         1.0                  N           141
# 3                 0.52         1.0                  N           244
# 6                 0.40         1.0                  N           170
# 26                0.70         1.0                  N           143
# 70                0.20         1.0                  N           140
# ...                ...         ...                ...           ...
# 2934970           0.80         1.0                  N           230
# 2934993           0.31         1.0                  N           231
# 2935034           0.21         1.0                  N            79
# 2935046           1.60         1.0                  N            43
# 2935073           0.60         1.0                  N            48
#
#          DOLocationID  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 2                 141             1  ...      0.5        2.00           0.0
# 3                 244             2  ...      0.5        0.00           0.0
# 6                 170             1  ...      0.5        2.35           0.0
# 26                143             1  ...      0.5        1.00           0.0
# 70                140             1  ...      0.5        1.88           0.0
# ...               ...           ...  ...      ...         ...           ...
# 2934970           230             1  ...      0.5        2.45           0.0
# 2934993           231             1  ...      0.5        2.03           0.0
# 2935034            79             2  ...      0.5        0.00           0.0
# 2935046            43             2  ...      0.5        0.00           0.0
# 2935073            48             2  ...      0.5        0.00           0.0
#
#          improvement_surcharge  total_amount  congestion_surcharge  \
# 2                          1.0         12.10                   2.5
# 3                          1.0          9.70                   0.0
# 6                          1.0         11.75                   2.5
# 26                         1.0         13.20                   2.5
# 70                         1.0         11.28                   2.5
# ...                        ...           ...                   ...
# 2934970                    1.0         14.70                   2.5
# 2934993                    1.0         12.18                   2.5
# 2935034                    1.0         10.15                   2.5
# 2935046                    1.0         16.85                   2.5
# 2935073                    1.0         10.85                   2.5
#
#          Airport_fee  cbd_congestion_fee  duration_min  speed_mph
# 2                0.0                0.00      1.950000  18.461538
# 3                0.0                0.00      5.566667   5.604790
# 6                0.0                0.00      1.466667  16.363636
# 26               0.0                0.00      5.283333   7.949527
# 70               0.0                0.00      2.050000   5.853659
# ...              ...                 ...           ...        ...
# 2934970          0.0                0.75      7.000000   6.857143
# 2934993          0.0                0.75      2.916667   6.377143
# 2935034          0.0                0.75      2.283333   5.518248
# 2935046          0.0                0.75     14.483333   6.628308
# 2935073          0.0                0.75      3.283333  10.964467
#
# [121075 rows x 22 columns]
